# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
data_fp = "./Runs/Jason_CaFluorescence/data/Jason_CaFluorescence.npy"
data = np.load(data_fp)
data
# Out:
# array([[ 0.00000000e+00, -9.71606687e-01],
#        [ 1.00002500e-02,  1.08469372e+00],
#        [ 2.00005000e-02,  2.31749641e+00],
#        ...,
#        [ 3.99979999e+02, -8.91485895e+01],
#        [ 3.99990000e+02, -9.19058369e+01],
#        [ 4.00000000e+02, -8.87156749e+01]])

# %%
plt.plot(data[:, 1])

# %% [markdown]
# F0 = 1
# KD = 1
# F(t)/F0 = Ca / (Ca + 1)
#
# 1. Solve system's parameters
# 2. Take Ca and Stimulus at each time step
# 3. Calculate the Florecnence from Ca

# %%
# check the stim.npy data in NaKL 
data_fp = "./Runs/NaKL/data/stim.npy"
data = np.load(data_fp)
len(data)
# Out:
# 40000

# %%
plt.plot(data[:, 1])
